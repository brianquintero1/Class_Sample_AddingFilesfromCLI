# %%
# Import Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
data_science = Path("data_science_salaries.csv")
data_science_df = pd.read_csv(data_science)
data_science_df
# Out:
#                      job_title experience_level employment_type work_models  \
# 0                Data Engineer        Mid-level       Full-time      Remote
# 1                Data Engineer        Mid-level       Full-time      Remote
# 2               Data Scientist     Senior-level       Full-time      Remote
# 3               Data Scientist     Senior-level       Full-time      Remote
# 4                 BI Developer        Mid-level       Full-time     On-site
# ...                        ...              ...             ...         ...
# 6594        Staff Data Analyst      Entry-level        Contract      Hybrid
# 6595        Staff Data Analyst  Executive-level       Full-time     On-site
# 6596  Machine Learning Manager     Senior-level       Full-time      Hybrid
# 6597             Data Engineer        Mid-level       Full-time      Hybrid
# 6598            Data Scientist     Senior-level       Full-time     On-site
#
# ...

# %%
data_science_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6599 entries, 0 to 6598
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_title           6599 non-null   object
#  1   experience_level    6599 non-null   object
#  2   employment_type     6599 non-null   object
#  3   work_models         6599 non-null   object
#  4   work_year           6599 non-null   int64
#  5   employee_residence  6599 non-null   object
#  6   salary              6599 non-null   int64
#  7   salary_currency     6599 non-null   object
#  8   salary_in_usd       6599 non-null   int64
#  9   company_location    6599 non-null   object
#  10  company_size        6599 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 567.2+ KB

# %%
data_science_df['job_title'].value_counts()
# Out:
# job_title
# Data Engineer                1307
# Data Scientist               1243
# Data Analyst                  910
# Machine Learning Engineer     629
# Analytics Engineer            246
#                              ...
# Deep Learning Researcher        1
# Power BI Developer              1
# Marketing Data Scientist        1
# AI Product Manager              1
# Sales Data Analyst              1
# Name: count, Length: 132, dtype: int64

# %%
data_science_df['job_title'] = data_science_df['job_title'].replace({'BI Data Analyst': 'Business Intelligence Analyst', 
                                                               'Power BI Developer': 'Business Intelligence Analyst',                                                              
                                                               'BI Developer': 'Business Intelligence Developer',
                                                               'BI Analyst': 'Business Intelligence Analyst',
                                                               'Business Data Analyst': 'Data Analyst',
                                                               'Big Data Engineer': 'Data Engineer',
                                                               'Data Science Manager': 'Data Scientist',
                                                               'Data Scientist Lead': 'Data Scientist',
                                                               'Data Infrastructure Engineer': 'Data Engineer',
                                                               'Data Operations Engineer': 'Data Engineer',
                                                               'Cloud Data Engineer': 'Data Engineer',
                                                               'Data Integration Engineer': 'Data Engineer',
                                                               'Data Management Analyst': 'Data Analyst',
                                                               'Financial Data Analyst': 'Data Analyst',
                                                               'Finance Data Analyst': 'Data Analyst',
                                                               'AI Architect': 'AI Related',
                                                               'AI Developer': 'AI Related',
                                                               'AI Engineer': 'AI Related',
                                                               'AI Product Manager': 'AI Related',
                                                               'AI Programmer': 'AI Related',
                                                               'AI Research Engineer': 'AI Related',
                                                               'AI Scientist': 'AI Related',
                                                               'Data Science': 'Data Scientist', 
                                                               'Data Visualization Analyst': 'Data Analyst',
                                                               'BI Data Engineer': 'Data Engineer',
                                                                'Data Visualization Engineer': 'Data Engineer',
                                                                'Head of Data Science': 'Data Scientist',
                                                                'Lead Data Analyst': 'Data Analyst',
                                                                'Lead Data Engineer': 'Data Engineer',
                                                                'Lead Data Scientist': 'Data Scientist',
                                                                'Lead Machine Learning Engineer': 'Machine Learning Engineer',
                                                                'Machine Learning Infrastructure Engineer': 'Machine Learning Engineer',
                                                                'Machine Learning Operations Engineer': 'Machine Learning Engineer',
                                                                'Machine Learning Research Engineer': 'Machine Learning Engineer',
                                                                'Machine Learning Software Engineer': 'Machine Learning Engineer',
                                                                'Marketing Data Engineer': 'Data Engineer',
                                                                'Marketing Data Scientist': 'Data Scientist',
                                                                'Marketing Data Analyst': 'Data Analyst',
                                                                'Principal Data Analyst': 'Data Analyst',
                                                                'Principal Data Engineer': 'Data Engineer',
                                                                'Principal Data Scientist': 'Data Scientist',
                                                                'Product Data Analyst': 'Data Analyst',
                                                                'Sales Data Analyst': 'Sales Data Analyst',
                                                                'Software Data Engineer': 'Data Engineer',
                                                                'Staff Data Analyst': 'Data Analyst',
                                                                'Staff Data Scientist': 'Data Scientist',
                                                                'Staff Machine Learning Engineer': 'Machine Learning Engineer',
                                                                'Principal Machine Learning Engineer': 'Machine Learning Engineer',})

# %%
data_science_df['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                   1422
# Data Engineer                    1367
# Data Analyst                      962
# Machine Learning Engineer         690
# Analytics Engineer                246
#                                  ...
# Consultant Data Engineer            1
# Deep Learning Researcher            1
# Analytics Engineering Manager       1
# AWS Data Architect                  1
# Sales Data Analyst                  1
# Name: count, Length: 86, dtype: int64

# %%
selected_job_titles = ["Data Scientist", "Data Engineer", "Data Analyst", "Machine Learning Engineer", "Analytics Engineer"]

data_science_df = data_science_df[data_science_df["job_title"].isin(selected_job_titles)]

data_science_df
# Out:
#            job_title experience_level employment_type work_models  work_year  \
# 0      Data Engineer        Mid-level       Full-time      Remote       2024
# 1      Data Engineer        Mid-level       Full-time      Remote       2024
# 2     Data Scientist     Senior-level       Full-time      Remote       2024
# 3     Data Scientist     Senior-level       Full-time      Remote       2024
# 8      Data Engineer  Executive-level       Full-time      Remote       2024
# ...              ...              ...             ...         ...        ...
# 6593  Data Scientist     Senior-level       Full-time      Remote       2020
# 6594    Data Analyst      Entry-level        Contract      Hybrid       2020
# 6595    Data Analyst  Executive-level       Full-time     On-site       2020
# 6597   Data Engineer        Mid-level       Full-time      Hybrid       2020
# 6598  Data Scientist     Senior-level       Full-time     On-site       2020
#
# ...

# %%
# data_science_df = data_science_df.set_index(["job_title"])
# data_science_df = data_science_df.loc[["Data Scientist", "Data Engineer", 
#                                        "Data Analyst", "Machine Learning Engineer", 
#                                        "Analytics Engineer"]]
# data_science_df

# %%
data_science_df= data_science_df.loc[data_science_df["salary_currency"] == "USD", :]
data_science_df
# Out:
#            job_title experience_level employment_type work_models  work_year  \
# 0      Data Engineer        Mid-level       Full-time      Remote       2024
# 1      Data Engineer        Mid-level       Full-time      Remote       2024
# 2     Data Scientist     Senior-level       Full-time      Remote       2024
# 3     Data Scientist     Senior-level       Full-time      Remote       2024
# 8      Data Engineer  Executive-level       Full-time      Remote       2024
# ...              ...              ...             ...         ...        ...
# 6556    Data Analyst      Entry-level        Contract      Remote       2020
# 6557  Data Scientist        Mid-level       Full-time     On-site       2020
# 6560   Data Engineer     Senior-level       Full-time      Hybrid       2020
# 6572    Data Analyst        Mid-level       Full-time     On-site       2020
# 6595    Data Analyst  Executive-level       Full-time     On-site       2020
#
# ...

# %%
data_science_df= data_science_df.loc[data_science_df["company_location"] == "United States", :]
data_science_df
# Out:
#            job_title experience_level employment_type work_models  work_year  \
# 0      Data Engineer        Mid-level       Full-time      Remote       2024
# 1      Data Engineer        Mid-level       Full-time      Remote       2024
# 2     Data Scientist     Senior-level       Full-time      Remote       2024
# 3     Data Scientist     Senior-level       Full-time      Remote       2024
# 8      Data Engineer  Executive-level       Full-time      Remote       2024
# ...              ...              ...             ...         ...        ...
# 6552  Data Scientist        Mid-level       Full-time      Remote       2020
# 6553   Data Engineer        Mid-level       Full-time      Remote       2020
# 6554  Data Scientist     Senior-level       Full-time      Remote       2020
# 6555  Data Scientist      Entry-level       Full-time      Remote       2020
# 6556    Data Analyst      Entry-level        Contract      Remote       2020
#
# ...

# %%
data_science_df["work_year"].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020], dtype=int64)

# %%
clean_data_df = data_science_df.loc[data_science_df["work_year"] != 2024]
clean_data_df
# Out:
#            job_title experience_level employment_type work_models  work_year  \
# 576   Data Scientist        Mid-level       Full-time      Remote       2023
# 577   Data Scientist        Mid-level       Full-time      Remote       2023
# 580    Data Engineer        Mid-level       Full-time      Remote       2023
# 581    Data Engineer        Mid-level       Full-time      Remote       2023
# 582     Data Analyst        Mid-level       Full-time     On-site       2023
# ...              ...              ...             ...         ...        ...
# 6552  Data Scientist        Mid-level       Full-time      Remote       2020
# 6553   Data Engineer        Mid-level       Full-time      Remote       2020
# 6554  Data Scientist     Senior-level       Full-time      Remote       2020
# 6555  Data Scientist      Entry-level       Full-time      Remote       2020
# 6556    Data Analyst      Entry-level        Contract      Remote       2020
#
# ...

# %%
#clean_data_df= clean_data_df.reset_index(drop=True)
#clean_data_df

# %%
clean_data_df
# Out:
#            job_title experience_level employment_type work_models  work_year  \
# 576   Data Scientist        Mid-level       Full-time      Remote       2023
# 577   Data Scientist        Mid-level       Full-time      Remote       2023
# 580    Data Engineer        Mid-level       Full-time      Remote       2023
# 581    Data Engineer        Mid-level       Full-time      Remote       2023
# 582     Data Analyst        Mid-level       Full-time     On-site       2023
# ...              ...              ...             ...         ...        ...
# 6552  Data Scientist        Mid-level       Full-time      Remote       2020
# 6553   Data Engineer        Mid-level       Full-time      Remote       2020
# 6554  Data Scientist     Senior-level       Full-time      Remote       2020
# 6555  Data Scientist      Entry-level       Full-time      Remote       2020
# 6556    Data Analyst      Entry-level        Contract      Remote       2020
#
# ...

# %%
# data_scientist_df = clean_data_df.loc[["Data Scientist"]]
# data_engineer_df = clean_data_df.loc[["Data Engineer"]]
# data_analyst_df = clean_data_df.loc[["Data Analyst"]]
# machine_learning_engineer_df = clean_data_df.loc[["Machine Learning Engineer"]]
# analytics_engineer_df = clean_data_df.loc[["Analytics Engineer"]]

# %%
data_scientist_df = clean_data_df[clean_data_df["job_title"] == 'Data Scientist']
df_ds = data_scientist_df.groupby('experience_level')['salary'].describe()

df_ds
# Out:
#                   count           mean           std      min       25%  \
# experience_level
# Entry-level        59.0  103041.372881  36658.109677  24000.0   74540.0
# Executive-level    33.0  211000.757576  72251.730798  78000.0  167875.0
# Mid-level         195.0  139557.702564  49980.792984  45760.0  105850.0
# Senior-level      746.0  175234.170241  58770.503831  38000.0  136650.5
#
#                        50%       75%       max
# experience_level
# Entry-level       100000.0  130000.0  190000.0
# Executive-level   218000.0  250000.0  416000.0
# Mid-level         131100.0  163500.0  310000.0
# Senior-level      169187.0  206000.0  750000.0

# %%
data_scientist_df[data_scientist_df["experience_level"] == 'Entry-level'].describe()
# Out:
#          work_year         salary  salary_in_usd
# count    59.000000      59.000000      59.000000
# mean   2022.576271  103041.372881  103041.372881
# std       0.724054   36658.109677   36658.109677
# min    2020.000000   24000.000000   24000.000000
# 25%    2022.000000   74540.000000   74540.000000
# 50%    2023.000000  100000.000000  100000.000000
# 75%    2023.000000  130000.000000  130000.000000
# max    2023.000000  190000.000000  190000.000000

# %%
data_scientist_df = clean_data_df[clean_data_df["job_title"] == 'Data Scientist']
data_engineer_df = clean_data_df[clean_data_df["job_title"] == 'Data Engineer']
data_analyst_df = clean_data_df[clean_data_df["job_title"] == 'Data Analyst']
machine_learning_engineer_df = clean_data_df[clean_data_df["job_title"] == 'Machine Learning Engineer']
analytics_engineer_df = clean_data_df[clean_data_df["job_title"] == 'Analytics Engineer']

df_ds = data_scientist_df.groupby('experience_level')['salary'].describe()
df_de = data_engineer_df.groupby('experience_level')['salary'].describe()
df_da = data_analyst_df.groupby('experience_level')['salary'].describe()
df_mle = machine_learning_engineer_df.groupby('experience_level')['salary'].describe()
df_ae = analytics_engineer_df.groupby('experience_level')['salary'].describe()

df_ds
df_de
df_da
df_mle
df_ae

df_ae

# data_scientist_df[data_scientist_df["experience_level"] == 'Mid-level'].describe()
# Out:
#                   count           mean            std       min       25%  \
# experience_level
# Entry-level         5.0  115930.000000   29759.107850   84000.0   90000.0
# Executive-level    12.0  185916.666667   34468.584731  135000.0  156000.0
# Mid-level          26.0  150394.807692  119138.417148   54000.0  100000.0
# Senior-level      149.0  162923.744966   63955.368071   48000.0  125000.0
#
#                        50%       75%       max
# experience_level
# Entry-level       119200.0  130000.0  156450.0
# Executive-level   187500.0  210000.0  250000.0
# Mid-level         121250.0  161250.0  700000.0
# Senior-level      152500.0  190000.0  700000.0

# %%
# Create DataFrames containing only specific Job Titles
data_scientist_df = clean_data_df[clean_data_df["job_title"] == 'Data Scientist']
data_engineer_df = clean_data_df[clean_data_df["job_title"] == 'Data Engineer']
data_analyst_df = clean_data_df[clean_data_df["job_title"] == 'Data Analyst']
machine_learning_engineer_df = clean_data_df[clean_data_df["job_title"] == 'Machine Learning Engineer']
analytics_engineer_df = clean_data_df[clean_data_df["job_title"] == 'Analytics Engineer']

# Create DataFrame describing statistical measures
df_ds = data_scientist_df.groupby('experience_level')['salary'].describe()
df_de = data_engineer_df.groupby('experience_level')['salary'].describe()
df_da = data_engineer_df.groupby('experience_level')['salary'].describe()
df_mle = machine_learning_engineer_df.groupby('experience_level')['salary'].describe()
df_ae = analytics_engineer_df.groupby('experience_level')['salary'].describe()

# Choose specific statistical measures and reformat
df_ds = df_ds[['count', 'mean', 'std']].assign(
    mean=lambda x: x['mean'].round(2).apply('{:,.0f}'.format),
    std=lambda x: x['std'].round(2).apply('{:,.0f}'.format),
    count=lambda x: x['count'].apply('{:,.0f}'.format)
)

df_de = df_de[['count', 'mean', 'std']].assign(
    mean=lambda x: x['mean'].round(2).apply('{:,.0f}'.format),
    std=lambda x: x['std'].round(2).apply('{:,.0f}'.format),
    count=lambda x: x['count'].apply('{:,.0f}'.format)
)

df_da = df_da[['count', 'mean', 'std']].assign(
    mean=lambda x: x['mean'].round(2).apply('{:,.0f}'.format),
    std=lambda x: x['std'].round(2).apply('{:,.0f}'.format),
    count=lambda x: x['count'].apply('{:,.0f}'.format)
)

df_mle = df_mle[['count', 'mean', 'std']].assign(
    mean=lambda x: x['mean'].round(2).apply('{:,.0f}'.format),
    std=lambda x: x['std'].round(2).apply('{:,.0f}'.format),
    count=lambda x: x['count'].apply('{:,.0f}'.format)
)
# df_ae
df_ae = df_ae[['count', 'mean', 'std']].assign(
    mean=lambda x: x['mean'].round(2).apply('{:,.0f}'.format),
    std=lambda x: x['std'].round(2).apply('{:,.0f}'.format),
    count=lambda x: x['count'].apply('{:,.0f}'.format)
)

# Create and add the Job Title column
df_ds['Job Title'] = 'Data Scientist'
df_de['Job Title'] = 'Data Engineer'
df_da['Job Title'] = 'Data Analyst'
df_mle['Job Title'] = 'Machine Learning Engineer'
df_ae['Job Title'] = 'Analytics Engineer'

# Combine the five individual Job Title DataFrames
combined_df = pd.concat([df_ds, df_de, df_da, df_mle, df_ae], axis=0)

combined_df.reset_index(inplace=True)

# Reorder Job Title column
combined_df = combined_df[['Job Title', 'experience_level', 'count', 'mean', 'std']]

combined_df


# experience_order = ['Entry-Level', 'Mid-Level', 'Senior-Level', 'Executive-Level']

# combined_df['experience_level'] = pd.Categorical(combined_df['experience_level'], categories=experience_order, ordered=True)

# combined_df = combined_df.sort_values(by='experience_level')
# Out:
#                     Job Title experience_level count     mean      std
# 0              Data Scientist      Entry-level    59  103,041   36,658
# 1              Data Scientist  Executive-level    33  211,001   72,252
# 2              Data Scientist        Mid-level   195  139,558   49,981
# 3              Data Scientist     Senior-level   746  175,234   58,770
# 4               Data Engineer      Entry-level    39   96,521   39,435
# 5               Data Engineer  Executive-level    74  201,025   73,655
# 6               Data Engineer        Mid-level   213  132,952   62,340
# 7               Data Engineer     Senior-level   685  163,092   57,493
# 8                Data Analyst      Entry-level    39   96,521   39,435
# 9                Data Analyst  Executive-level    74  201,025   73,655
# 10               Data Analyst        Mid-level   213  132,952   62,340
# 11               Data Analyst     Senior-level   685  163,092   57,493
# ...

# %%
experience_level_order = {
    'Entry-level': 1,
    'Mid-level': 2,
    'Senior-level': 3,
    'Executive-level': 4
}

combined_df['experience_level_order'] = combined_df['experience_level'].map(experience_level_order)

combined_df_sorted = combined_df.sort_values(by=['Job Title', 'experience_level_order'])

combined_df_sorted = combined_df_sorted.drop('experience_level_order', axis=1)

combined_df_sorted.reset_index(drop=True, inplace=True)

combined_df_sorted
# Out:
#                     Job Title experience_level count     mean      std
# 0          Analytics Engineer      Entry-level     5  115,930   29,759
# 1          Analytics Engineer        Mid-level    26  150,395  119,138
# 2          Analytics Engineer     Senior-level   149  162,924   63,955
# 3          Analytics Engineer  Executive-level    12  185,917   34,469
# 4                Data Analyst      Entry-level    39   96,521   39,435
# 5                Data Analyst        Mid-level   213  132,952   62,340
# 6                Data Analyst     Senior-level   685  163,092   57,493
# 7                Data Analyst  Executive-level    74  201,025   73,655
# 8               Data Engineer      Entry-level    39   96,521   39,435
# 9               Data Engineer        Mid-level   213  132,952   62,340
# 10              Data Engineer     Senior-level   685  163,092   57,493
# 11              Data Engineer  Executive-level    74  201,025   73,655
# ...

# %%
# Assuming your DataFrame is named df
# Convert 'mean' salary data to numeric if it's not already
combined_df_sorted['mean'] = combined_df_sorted['mean'].str.replace(',', '').astype(float)

# # Get unique job titles
# unique_job_titles = combined_df_sorted['Job Title'].unique()

# # Create a box plot for each job title
# for job_title in unique_job_titles:
#     # Filter the DataFrame for the current job title
#     filtered_df = combined_df_sorted[combined_df_sorted['Job Title'] == job_title]
    
#     # Pivot the filtered DataFrame
#     pivot_df = filtered_df.pivot(index='Job Title', columns='experience_level', values='mean').T
    
#     # Plotting
#     plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
#     pivot_df.plot(kind='box', vert=False)  # Use a horizontal box plot for readability
#     plt.title(f'Salary Distribution by Experience Level for {job_title}')
#     plt.xlabel('Mean Salary ($)')
#     plt.ylabel('Experience Level')
#     plt.grid(True)  # Optionally enable the grid for better precision
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 3
#       1 # Assuming your DataFrame is named df
#       2 # Convert 'mean' salary data to numeric if it's not already
# ----> 3 combined_df_sorted['mean'] = combined_df_sorted['mean'].str.replace(',', '').astype(float)
#
# File c:\Users\Admin\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File c:\Users\Admin\anaconda3\envs\dev\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
# ...

# %%
# Assuming your DataFrame is named df
# If your 'mean' salary data contains commas or is formatted as strings, convert it to numeric
combined_df_sorted['mean'] = combined_df_sorted['mean'].str.replace(',', '').astype(float)

# Pivot the DataFrame to get each experience level as a column for each job title
pivot_df = df.pivot_table(index='Job Title', columns='experience_level', values='mean')

# Plotting
plt.figure(figsize=(12, 8))  # Adjust the figure size as needed
pivot_df.boxplot()
plt.title('Salary Distribution by Experience Level for Each Job Title')
plt.ylabel('Mean Salary ($)')
plt.xlabel('Job Title')
plt.xticks(rotation=45)  # Rotate the job titles for better readability
plt.grid(False)  # Optionally remove the grid for a cleaner look
plt.show()

# %%
data = {
    'Job Title': ['Analytics Engineer', 'Analytics Engineer', 'Analytics Engineer', 'Analytics Engineer',
                  'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst',
                  'Data Engineer', 'Data Engineer', 'Data Engineer', 'Data Engineer',
                  'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist',
                  'Machine Learning Engineer', 'Machine Learning Engineer', 'Machine Learning Engineer', 'Machine Learning Engineer'],
    'experience_level': ['Entry-level', 'Mid-level', 'Senior-level', 'Executive-level',
                         'Entry-level', 'Mid-level', 'Senior-level', 'Executive-level',
                         'Entry-level', 'Mid-level', 'Senior-level', 'Executive-level',
                         'Entry-level', 'Mid-level', 'Senior-level', 'Executive-level',
                         'Entry-level', 'Mid-level', 'Senior-level', 'Executive-level'],
    'count': [5, 26, 149, 12, 39, 213, 685, 74, 39, 213, 685, 74, 59, 195, 746, 33, 18, 72, 383, 6],
    'mean': [115930, 150395, 162924, 185917, 96521, 132952, 163092, 201025, 96521, 132952, 163092, 201025, 103041, 139558, 175234, 211001, 122520, 175197, 195200, 190950],
    'std': [29759, 119138, 63955, 34469, 39435, 62340, 57493, 73655, 39435, 62340, 57493, 73655, 36658, 49981, 58770, 72252, 51647, 86549, 59814, 54525]
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'mean' salaries to thousands for easier handling and visualization
df['mean'] /= 1000

# Creating the box plot
fig, ax = plt.subplots(figsize=(10, 8))
df.boxplot(column='mean', by='experience_level', ax=ax)

# Customizing the plot
plt.title('Mean Salary Distribution by Experience Level for Different Job Titles')
plt.suptitle('')  # Remove the default subtitle to clean up the plot
plt.xlabel('Experience Level')
plt.ylabel('Mean Salary (in thousands)')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.grid(False)  # Optionally, turn off the grid for a cleaner look

# Display the plot
plt.show()

# %%
#Comparison of different experience levels of a position under the same title (salary they earn)

# %%
#title_vs_salary_df = data_df.sort_values("work_year")
#title_vs_salary_df

# %%
#group_title_vs_salary_df = data_df.groupby(["job_title"])
#print(group_title_vs_salary_df)
#group_title_vs_salary_df.head()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
data_scientist = data_scientist_df.groupby(["experience_level"])["salary"].mean()

data_scientist.head()
# Out:
# experience_level
# Entry-level        103041.372881
# Executive-level    211000.757576
# Mid-level          139557.702564
# Senior-level       175234.170241
# Name: salary, dtype: float64

# %%
data_engineer = data_engineer_df.groupby(["experience_level"])["salary"].mean()
data_analyst = data_analyst_df.groupby(["experience_level"])["salary"].mean()
machine_learning_engineer = machine_learning_engineer_df.groupby(["experience_level"])["salary"].mean()
analytics_engineer = analytics_engineer_df.groupby(["experience_level"])["salary"].mean()

# %%
data_engineer
# Out:
# experience_level
# Entry-level         96521.179487
# Executive-level    201025.162162
# Mid-level          132951.957746
# Senior-level       163092.500730
# Name: salary, dtype: float64

# %%
data_analyst
# Out:
# experience_level
# Entry-level         83766.299065
# Executive-level    114107.142857
# Mid-level          101796.349462
# Senior-level       125690.291045
# Name: salary, dtype: float64

# %%
data_scientist = data_scientist.plot(kind = 'bar') 
plt.xlabel("Experience Level")
plt.ylabel("Average Salary")
plt.title("Data Scientist - Experience VS Salary")
plt.show()
plt.show()

# %%
data_engineer = data_engineer.plot(kind = 'bar') 
plt.xlabel("Experience Level")
plt.ylabel("Average Salary")
plt.title("Data Engineer - Experience VS Salary")
plt.show()
plt.show()

# %%
data_analyst  = data_analyst.plot(kind = 'bar') 
plt.xlabel("Experience Level")
plt.ylabel("Average Salary")
plt.title("Data Analyst - Experience VS Salary")
plt.show()
plt.show()

# %%
machine_learning_engineer = machine_learning_engineer.plot(kind = 'bar') 
plt.xlabel("Experience Level")
plt.ylabel("Average Salary")
plt.title("Machine Learning Engineer- Experience VS Salary")
plt.show()
plt.show()

# %%
analytics_engineer = analytics_engineer.plot(kind = 'bar') 
plt.xlabel("Experience Level")
plt.ylabel("Average Salary")
plt.title("Analytics Engineer- Experience VS Salary")
plt.show()
plt.show()
